# %% [markdown]
# # **1. 모델 설계**

# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

from tqdm.notebook import tqdm

device = "cuda:0" if torch.cuda.is_available() else "cpu"
device = torch.device(device)
print(device)
# Out:
# cuda:0

# %% [markdown]
# 데이터 다운: https://www.kaggle.com/datasets/dansbecker/cityscapes-image-pairs

# %%
# username, key setting
os.environ["KAGGLE_USERNAME"] = "my_name"
os.environ["KAGGLE_KEY"] = "my_key"

# data download
# !kaggle datasets download -d dansbecker/cityscapes-image-pairs -p /root/Assignment/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dansbecker/cityscapes-image-pairs
# License(s): other
# Downloading cityscapes-image-pairs.zip to /root/Assignment
# 100%|████████████████████████████████████████| 202M/202M [00:18<00:00, 11.9MB/s]
# 100%|████████████████████████████████████████| 202M/202M [00:18<00:00, 11.2MB/s]

# %%
# !unzip /root/Assignment/cityscapes-image-pairs.zip -d /root/Assignment/
# Out:
# Archive:  /root/Assignment/cityscapes-image-pairs.zip
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/10.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/100.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1000.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1001.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1002.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1003.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1004.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1005.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1006.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1007.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1008.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1009.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/101.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1010.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1011.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1012.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1013.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1014.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1015.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1016.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1017.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1018.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1019.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/102.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1020.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1021.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1022.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1023.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1024.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1025.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1026.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1027.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1028.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1029.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/103.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1030.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1031.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1032.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1033.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1034.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1035.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1036.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1037.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1038.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1039.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/104.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1040.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1041.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1042.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1043.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1044.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1045.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1046.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1047.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1048.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1049.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/105.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1050.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1051.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1052.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1053.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1054.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1055.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1056.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1057.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1058.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1059.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/106.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1060.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1061.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1062.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1063.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1064.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1065.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1066.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1067.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1068.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1069.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/107.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1070.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1071.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1072.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1073.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1074.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1075.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1076.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1077.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1078.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1079.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/108.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1080.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1081.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1082.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1083.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1084.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1085.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1086.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1087.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1088.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1089.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/109.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1090.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1091.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1092.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1093.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1094.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1095.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1096.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1097.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1098.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1099.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/11.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/110.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1100.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1101.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1102.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1103.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1104.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1105.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1106.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1107.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1108.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1109.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/111.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1110.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1111.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1112.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1113.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1114.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1115.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1116.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1117.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1118.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1119.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/112.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1120.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1121.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1122.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1123.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1124.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1125.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1126.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1127.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1128.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1129.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/113.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1130.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1131.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1132.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1133.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1134.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1135.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1136.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1137.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1138.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1139.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/114.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1140.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1141.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1142.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1143.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1144.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1145.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1146.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1147.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1148.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1149.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/115.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1150.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1151.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1152.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1153.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1154.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1155.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1156.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1157.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1158.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1159.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/116.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1160.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1161.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1162.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1163.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1164.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1165.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1166.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1167.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1168.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1169.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/117.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1170.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1171.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1172.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1173.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1174.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1175.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1176.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1177.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1178.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1179.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/118.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1180.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1181.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1182.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1183.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1184.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1185.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1186.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1187.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1188.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1189.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/119.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1190.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1191.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1192.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1193.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1194.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1195.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1196.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1197.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1198.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1199.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/12.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/120.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1200.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1201.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1202.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1203.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1204.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1205.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1206.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1207.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1208.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1209.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/121.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1210.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1211.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1212.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1213.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1214.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1215.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1216.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1217.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1218.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1219.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/122.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1220.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1221.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1222.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1223.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1224.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1225.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1226.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1227.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1228.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1229.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/123.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1230.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1231.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1232.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1233.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1234.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1235.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1236.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1237.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1238.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1239.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/124.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1240.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1241.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1242.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1243.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1244.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1245.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1246.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1247.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1248.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1249.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/125.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1250.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1251.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1252.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1253.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1254.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1255.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1256.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1257.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1258.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1259.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/126.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1260.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1261.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1262.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1263.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1264.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1265.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1266.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1267.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1268.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1269.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/127.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1270.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1271.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1272.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1273.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1274.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1275.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1276.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1277.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1278.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1279.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/128.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1280.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1281.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1282.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1283.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1284.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1285.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1286.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1287.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1288.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1289.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/129.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1290.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1291.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1292.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1293.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1294.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1295.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1296.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1297.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1298.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1299.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/13.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/130.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1300.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1301.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1302.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1303.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1304.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1305.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1306.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1307.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1308.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1309.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/131.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1310.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1311.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1312.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1313.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1314.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1315.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1316.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1317.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1318.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1319.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/132.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1320.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1321.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1322.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1323.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1324.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1325.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1326.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1327.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1328.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1329.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/133.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1330.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1331.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1332.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1333.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1334.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1335.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1336.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1337.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1338.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1339.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/134.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1340.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1341.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1342.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1343.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1344.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1345.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1346.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1347.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1348.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1349.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/135.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1350.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1351.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1352.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1353.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1354.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1355.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1356.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1357.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1358.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1359.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/136.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1360.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1361.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1362.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1363.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1364.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1365.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1366.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1367.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1368.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1369.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/137.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1370.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1371.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1372.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1373.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1374.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1375.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1376.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1377.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1378.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1379.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/138.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1380.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1381.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1382.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1383.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1384.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1385.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1386.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1387.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1388.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1389.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/139.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1390.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1391.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1392.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1393.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1394.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1395.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1396.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1397.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1398.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1399.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/14.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/140.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1400.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1401.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1402.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1403.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1404.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1405.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1406.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1407.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1408.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1409.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/141.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1410.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1411.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1412.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1413.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1414.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1415.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1416.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1417.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1418.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1419.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/142.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1420.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1421.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1422.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1423.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1424.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1425.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1426.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1427.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1428.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1429.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/143.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1430.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1431.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1432.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1433.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1434.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1435.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1436.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1437.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1438.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1439.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/144.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1440.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1441.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1442.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1443.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1444.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1445.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1446.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1447.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1448.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1449.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/145.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1450.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1451.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1452.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1453.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1454.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1455.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1456.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1457.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1458.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1459.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/146.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1460.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1461.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1462.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1463.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1464.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1465.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1466.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1467.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1468.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1469.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/147.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1470.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1471.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1472.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1473.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1474.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1475.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1476.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1477.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1478.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1479.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/148.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1480.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1481.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1482.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1483.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1484.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1485.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1486.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1487.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1488.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1489.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/149.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1490.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1491.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1492.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1493.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1494.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1495.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1496.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1497.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1498.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1499.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/15.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/150.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1500.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1501.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1502.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1503.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1504.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1505.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1506.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1507.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1508.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1509.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/151.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1510.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1511.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1512.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1513.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1514.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1515.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1516.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1517.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1518.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1519.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/152.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1520.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1521.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1522.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1523.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1524.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1525.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1526.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1527.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1528.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1529.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/153.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1530.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1531.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1532.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1533.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1534.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1535.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1536.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1537.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1538.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1539.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/154.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1540.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1541.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1542.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1543.jpg
#   inflating: /root/Assignment/cityscapes_data/cityscapes_data/train/1544.jpg
# ...
#   inflating: /root/Assignment/cityscapes_data/val/308.jpg
#   inflating: /root/Assignment/cityscapes_data/val/309.jpg
#   inflating: /root/Assignment/cityscapes_data/val/31.jpg
#   inflating: /root/Assignment/cityscapes_data/val/310.jpg
#   inflating: /root/Assignment/cityscapes_data/val/311.jpg
#   inflating: /root/Assignment/cityscapes_data/val/312.jpg
#   inflating: /root/Assignment/cityscapes_data/val/313.jpg
#   inflating: /root/Assignment/cityscapes_data/val/314.jpg
#   inflating: /root/Assignment/cityscapes_data/val/315.jpg
#   inflating: /root/Assignment/cityscapes_data/val/316.jpg
#   inflating: /root/Assignment/cityscapes_data/val/317.jpg
#   inflating: /root/Assignment/cityscapes_data/val/318.jpg
#   inflating: /root/Assignment/cityscapes_data/val/319.jpg
#   inflating: /root/Assignment/cityscapes_data/val/32.jpg
#   inflating: /root/Assignment/cityscapes_data/val/320.jpg
#   inflating: /root/Assignment/cityscapes_data/val/321.jpg
#   inflating: /root/Assignment/cityscapes_data/val/322.jpg
#   inflating: /root/Assignment/cityscapes_data/val/323.jpg
#   inflating: /root/Assignment/cityscapes_data/val/324.jpg
#   inflating: /root/Assignment/cityscapes_data/val/325.jpg
#   inflating: /root/Assignment/cityscapes_data/val/326.jpg
#   inflating: /root/Assignment/cityscapes_data/val/327.jpg
#   inflating: /root/Assignment/cityscapes_data/val/328.jpg
#   inflating: /root/Assignment/cityscapes_data/val/329.jpg
#   inflating: /root/Assignment/cityscapes_data/val/33.jpg
#   inflating: /root/Assignment/cityscapes_data/val/330.jpg
#   inflating: /root/Assignment/cityscapes_data/val/331.jpg
#   inflating: /root/Assignment/cityscapes_data/val/332.jpg
#   inflating: /root/Assignment/cityscapes_data/val/333.jpg
#   inflating: /root/Assignment/cityscapes_data/val/334.jpg
#   inflating: /root/Assignment/cityscapes_data/val/335.jpg
#   inflating: /root/Assignment/cityscapes_data/val/336.jpg
#   inflating: /root/Assignment/cityscapes_data/val/337.jpg
#   inflating: /root/Assignment/cityscapes_data/val/338.jpg
#   inflating: /root/Assignment/cityscapes_data/val/339.jpg
#   inflating: /root/Assignment/cityscapes_data/val/34.jpg
#   inflating: /root/Assignment/cityscapes_data/val/340.jpg
#   inflating: /root/Assignment/cityscapes_data/val/341.jpg
#   inflating: /root/Assignment/cityscapes_data/val/342.jpg
#   inflating: /root/Assignment/cityscapes_data/val/343.jpg
#   inflating: /root/Assignment/cityscapes_data/val/344.jpg
#   inflating: /root/Assignment/cityscapes_data/val/345.jpg
#   inflating: /root/Assignment/cityscapes_data/val/346.jpg
#   inflating: /root/Assignment/cityscapes_data/val/347.jpg
#   inflating: /root/Assignment/cityscapes_data/val/348.jpg
#   inflating: /root/Assignment/cityscapes_data/val/349.jpg
#   inflating: /root/Assignment/cityscapes_data/val/35.jpg
#   inflating: /root/Assignment/cityscapes_data/val/350.jpg
#   inflating: /root/Assignment/cityscapes_data/val/351.jpg
#   inflating: /root/Assignment/cityscapes_data/val/352.jpg
#   inflating: /root/Assignment/cityscapes_data/val/353.jpg
#   inflating: /root/Assignment/cityscapes_data/val/354.jpg
#   inflating: /root/Assignment/cityscapes_data/val/355.jpg
#   inflating: /root/Assignment/cityscapes_data/val/356.jpg
#   inflating: /root/Assignment/cityscapes_data/val/357.jpg
#   inflating: /root/Assignment/cityscapes_data/val/358.jpg
#   inflating: /root/Assignment/cityscapes_data/val/359.jpg
#   inflating: /root/Assignment/cityscapes_data/val/36.jpg
#   inflating: /root/Assignment/cityscapes_data/val/360.jpg
#   inflating: /root/Assignment/cityscapes_data/val/361.jpg
#   inflating: /root/Assignment/cityscapes_data/val/362.jpg
#   inflating: /root/Assignment/cityscapes_data/val/363.jpg
#   inflating: /root/Assignment/cityscapes_data/val/364.jpg
#   inflating: /root/Assignment/cityscapes_data/val/365.jpg
#   inflating: /root/Assignment/cityscapes_data/val/366.jpg
#   inflating: /root/Assignment/cityscapes_data/val/367.jpg
#   inflating: /root/Assignment/cityscapes_data/val/368.jpg
#   inflating: /root/Assignment/cityscapes_data/val/369.jpg
#   inflating: /root/Assignment/cityscapes_data/val/37.jpg
#   inflating: /root/Assignment/cityscapes_data/val/370.jpg
#   inflating: /root/Assignment/cityscapes_data/val/371.jpg
#   inflating: /root/Assignment/cityscapes_data/val/372.jpg
#   inflating: /root/Assignment/cityscapes_data/val/373.jpg
#   inflating: /root/Assignment/cityscapes_data/val/374.jpg
#   inflating: /root/Assignment/cityscapes_data/val/375.jpg
#   inflating: /root/Assignment/cityscapes_data/val/376.jpg
#   inflating: /root/Assignment/cityscapes_data/val/377.jpg
#   inflating: /root/Assignment/cityscapes_data/val/378.jpg
#   inflating: /root/Assignment/cityscapes_data/val/379.jpg
#   inflating: /root/Assignment/cityscapes_data/val/38.jpg
#   inflating: /root/Assignment/cityscapes_data/val/380.jpg
#   inflating: /root/Assignment/cityscapes_data/val/381.jpg
#   inflating: /root/Assignment/cityscapes_data/val/382.jpg
#   inflating: /root/Assignment/cityscapes_data/val/383.jpg
#   inflating: /root/Assignment/cityscapes_data/val/384.jpg
#   inflating: /root/Assignment/cityscapes_data/val/385.jpg
#   inflating: /root/Assignment/cityscapes_data/val/386.jpg
#   inflating: /root/Assignment/cityscapes_data/val/387.jpg
#   inflating: /root/Assignment/cityscapes_data/val/388.jpg
#   inflating: /root/Assignment/cityscapes_data/val/389.jpg
#   inflating: /root/Assignment/cityscapes_data/val/39.jpg
#   inflating: /root/Assignment/cityscapes_data/val/390.jpg
#   inflating: /root/Assignment/cityscapes_data/val/391.jpg
#   inflating: /root/Assignment/cityscapes_data/val/392.jpg
#   inflating: /root/Assignment/cityscapes_data/val/393.jpg
#   inflating: /root/Assignment/cityscapes_data/val/394.jpg
#   inflating: /root/Assignment/cityscapes_data/val/395.jpg
#   inflating: /root/Assignment/cityscapes_data/val/396.jpg
#   inflating: /root/Assignment/cityscapes_data/val/397.jpg
#   inflating: /root/Assignment/cityscapes_data/val/398.jpg
#   inflating: /root/Assignment/cityscapes_data/val/399.jpg
#   inflating: /root/Assignment/cityscapes_data/val/4.jpg
#   inflating: /root/Assignment/cityscapes_data/val/40.jpg
#   inflating: /root/Assignment/cityscapes_data/val/400.jpg
#   inflating: /root/Assignment/cityscapes_data/val/401.jpg
#   inflating: /root/Assignment/cityscapes_data/val/402.jpg
#   inflating: /root/Assignment/cityscapes_data/val/403.jpg
#   inflating: /root/Assignment/cityscapes_data/val/404.jpg
#   inflating: /root/Assignment/cityscapes_data/val/405.jpg
#   inflating: /root/Assignment/cityscapes_data/val/406.jpg
#   inflating: /root/Assignment/cityscapes_data/val/407.jpg
#   inflating: /root/Assignment/cityscapes_data/val/408.jpg
#   inflating: /root/Assignment/cityscapes_data/val/409.jpg
#   inflating: /root/Assignment/cityscapes_data/val/41.jpg
#   inflating: /root/Assignment/cityscapes_data/val/410.jpg
#   inflating: /root/Assignment/cityscapes_data/val/411.jpg
#   inflating: /root/Assignment/cityscapes_data/val/412.jpg
#   inflating: /root/Assignment/cityscapes_data/val/413.jpg
#   inflating: /root/Assignment/cityscapes_data/val/414.jpg
#   inflating: /root/Assignment/cityscapes_data/val/415.jpg
#   inflating: /root/Assignment/cityscapes_data/val/416.jpg
#   inflating: /root/Assignment/cityscapes_data/val/417.jpg
#   inflating: /root/Assignment/cityscapes_data/val/418.jpg
#   inflating: /root/Assignment/cityscapes_data/val/419.jpg
#   inflating: /root/Assignment/cityscapes_data/val/42.jpg
#   inflating: /root/Assignment/cityscapes_data/val/420.jpg
#   inflating: /root/Assignment/cityscapes_data/val/421.jpg
#   inflating: /root/Assignment/cityscapes_data/val/422.jpg
#   inflating: /root/Assignment/cityscapes_data/val/423.jpg
#   inflating: /root/Assignment/cityscapes_data/val/424.jpg
#   inflating: /root/Assignment/cityscapes_data/val/425.jpg
#   inflating: /root/Assignment/cityscapes_data/val/426.jpg
#   inflating: /root/Assignment/cityscapes_data/val/427.jpg
#   inflating: /root/Assignment/cityscapes_data/val/428.jpg
#   inflating: /root/Assignment/cityscapes_data/val/429.jpg
#   inflating: /root/Assignment/cityscapes_data/val/43.jpg
#   inflating: /root/Assignment/cityscapes_data/val/430.jpg
#   inflating: /root/Assignment/cityscapes_data/val/431.jpg
#   inflating: /root/Assignment/cityscapes_data/val/432.jpg
#   inflating: /root/Assignment/cityscapes_data/val/433.jpg
#   inflating: /root/Assignment/cityscapes_data/val/434.jpg
#   inflating: /root/Assignment/cityscapes_data/val/435.jpg
#   inflating: /root/Assignment/cityscapes_data/val/436.jpg
#   inflating: /root/Assignment/cityscapes_data/val/437.jpg
#   inflating: /root/Assignment/cityscapes_data/val/438.jpg
#   inflating: /root/Assignment/cityscapes_data/val/439.jpg
#   inflating: /root/Assignment/cityscapes_data/val/44.jpg
#   inflating: /root/Assignment/cityscapes_data/val/440.jpg
#   inflating: /root/Assignment/cityscapes_data/val/441.jpg
#   inflating: /root/Assignment/cityscapes_data/val/442.jpg
#   inflating: /root/Assignment/cityscapes_data/val/443.jpg
#   inflating: /root/Assignment/cityscapes_data/val/444.jpg
#   inflating: /root/Assignment/cityscapes_data/val/445.jpg
#   inflating: /root/Assignment/cityscapes_data/val/446.jpg
#   inflating: /root/Assignment/cityscapes_data/val/447.jpg
#   inflating: /root/Assignment/cityscapes_data/val/448.jpg
#   inflating: /root/Assignment/cityscapes_data/val/449.jpg
#   inflating: /root/Assignment/cityscapes_data/val/45.jpg
#   inflating: /root/Assignment/cityscapes_data/val/450.jpg
#   inflating: /root/Assignment/cityscapes_data/val/451.jpg
#   inflating: /root/Assignment/cityscapes_data/val/452.jpg
#   inflating: /root/Assignment/cityscapes_data/val/453.jpg
#   inflating: /root/Assignment/cityscapes_data/val/454.jpg
#   inflating: /root/Assignment/cityscapes_data/val/455.jpg
#   inflating: /root/Assignment/cityscapes_data/val/456.jpg
#   inflating: /root/Assignment/cityscapes_data/val/457.jpg
#   inflating: /root/Assignment/cityscapes_data/val/458.jpg
#   inflating: /root/Assignment/cityscapes_data/val/459.jpg
#   inflating: /root/Assignment/cityscapes_data/val/46.jpg
#   inflating: /root/Assignment/cityscapes_data/val/460.jpg
#   inflating: /root/Assignment/cityscapes_data/val/461.jpg
#   inflating: /root/Assignment/cityscapes_data/val/462.jpg
#   inflating: /root/Assignment/cityscapes_data/val/463.jpg
#   inflating: /root/Assignment/cityscapes_data/val/464.jpg
#   inflating: /root/Assignment/cityscapes_data/val/465.jpg
#   inflating: /root/Assignment/cityscapes_data/val/466.jpg
#   inflating: /root/Assignment/cityscapes_data/val/467.jpg
#   inflating: /root/Assignment/cityscapes_data/val/468.jpg
#   inflating: /root/Assignment/cityscapes_data/val/469.jpg
#   inflating: /root/Assignment/cityscapes_data/val/47.jpg
#   inflating: /root/Assignment/cityscapes_data/val/470.jpg
#   inflating: /root/Assignment/cityscapes_data/val/471.jpg
#   inflating: /root/Assignment/cityscapes_data/val/472.jpg
#   inflating: /root/Assignment/cityscapes_data/val/473.jpg
#   inflating: /root/Assignment/cityscapes_data/val/474.jpg
#   inflating: /root/Assignment/cityscapes_data/val/475.jpg
#   inflating: /root/Assignment/cityscapes_data/val/476.jpg
#   inflating: /root/Assignment/cityscapes_data/val/477.jpg
#   inflating: /root/Assignment/cityscapes_data/val/478.jpg
#   inflating: /root/Assignment/cityscapes_data/val/479.jpg
#   inflating: /root/Assignment/cityscapes_data/val/48.jpg
#   inflating: /root/Assignment/cityscapes_data/val/480.jpg
#   inflating: /root/Assignment/cityscapes_data/val/481.jpg
#   inflating: /root/Assignment/cityscapes_data/val/482.jpg
#   inflating: /root/Assignment/cityscapes_data/val/483.jpg
#   inflating: /root/Assignment/cityscapes_data/val/484.jpg
#   inflating: /root/Assignment/cityscapes_data/val/485.jpg
#   inflating: /root/Assignment/cityscapes_data/val/486.jpg
#   inflating: /root/Assignment/cityscapes_data/val/487.jpg
#   inflating: /root/Assignment/cityscapes_data/val/488.jpg
#   inflating: /root/Assignment/cityscapes_data/val/489.jpg
#   inflating: /root/Assignment/cityscapes_data/val/49.jpg
#   inflating: /root/Assignment/cityscapes_data/val/490.jpg
#   inflating: /root/Assignment/cityscapes_data/val/491.jpg
#   inflating: /root/Assignment/cityscapes_data/val/492.jpg
#   inflating: /root/Assignment/cityscapes_data/val/493.jpg
#   inflating: /root/Assignment/cityscapes_data/val/494.jpg
#   inflating: /root/Assignment/cityscapes_data/val/495.jpg
#   inflating: /root/Assignment/cityscapes_data/val/496.jpg
#   inflating: /root/Assignment/cityscapes_data/val/497.jpg
#   inflating: /root/Assignment/cityscapes_data/val/498.jpg
#   inflating: /root/Assignment/cityscapes_data/val/499.jpg
#   inflating: /root/Assignment/cityscapes_data/val/5.jpg
#   inflating: /root/Assignment/cityscapes_data/val/50.jpg
#   inflating: /root/Assignment/cityscapes_data/val/500.jpg
#   inflating: /root/Assignment/cityscapes_data/val/51.jpg
#   inflating: /root/Assignment/cityscapes_data/val/52.jpg
#   inflating: /root/Assignment/cityscapes_data/val/53.jpg
#   inflating: /root/Assignment/cityscapes_data/val/54.jpg
#   inflating: /root/Assignment/cityscapes_data/val/55.jpg
#   inflating: /root/Assignment/cityscapes_data/val/56.jpg
#   inflating: /root/Assignment/cityscapes_data/val/57.jpg
#   inflating: /root/Assignment/cityscapes_data/val/58.jpg
#   inflating: /root/Assignment/cityscapes_data/val/59.jpg
#   inflating: /root/Assignment/cityscapes_data/val/6.jpg
#   inflating: /root/Assignment/cityscapes_data/val/60.jpg
#   inflating: /root/Assignment/cityscapes_data/val/61.jpg
#   inflating: /root/Assignment/cityscapes_data/val/62.jpg
#   inflating: /root/Assignment/cityscapes_data/val/63.jpg
#   inflating: /root/Assignment/cityscapes_data/val/64.jpg
#   inflating: /root/Assignment/cityscapes_data/val/65.jpg
#   inflating: /root/Assignment/cityscapes_data/val/66.jpg
#   inflating: /root/Assignment/cityscapes_data/val/67.jpg
#   inflating: /root/Assignment/cityscapes_data/val/68.jpg
#   inflating: /root/Assignment/cityscapes_data/val/69.jpg
#   inflating: /root/Assignment/cityscapes_data/val/7.jpg
#   inflating: /root/Assignment/cityscapes_data/val/70.jpg
#   inflating: /root/Assignment/cityscapes_data/val/71.jpg
#   inflating: /root/Assignment/cityscapes_data/val/72.jpg
#   inflating: /root/Assignment/cityscapes_data/val/73.jpg
#   inflating: /root/Assignment/cityscapes_data/val/74.jpg
#   inflating: /root/Assignment/cityscapes_data/val/75.jpg
#   inflating: /root/Assignment/cityscapes_data/val/76.jpg
#   inflating: /root/Assignment/cityscapes_data/val/77.jpg
#   inflating: /root/Assignment/cityscapes_data/val/78.jpg
#   inflating: /root/Assignment/cityscapes_data/val/79.jpg
#   inflating: /root/Assignment/cityscapes_data/val/8.jpg
#   inflating: /root/Assignment/cityscapes_data/val/80.jpg
#   inflating: /root/Assignment/cityscapes_data/val/81.jpg
#   inflating: /root/Assignment/cityscapes_data/val/82.jpg
#   inflating: /root/Assignment/cityscapes_data/val/83.jpg
#   inflating: /root/Assignment/cityscapes_data/val/84.jpg
#   inflating: /root/Assignment/cityscapes_data/val/85.jpg
#   inflating: /root/Assignment/cityscapes_data/val/86.jpg
#   inflating: /root/Assignment/cityscapes_data/val/87.jpg
#   inflating: /root/Assignment/cityscapes_data/val/88.jpg
#   inflating: /root/Assignment/cityscapes_data/val/89.jpg
#   inflating: /root/Assignment/cityscapes_data/val/9.jpg
#   inflating: /root/Assignment/cityscapes_data/val/90.jpg
#   inflating: /root/Assignment/cityscapes_data/val/91.jpg
#   inflating: /root/Assignment/cityscapes_data/val/92.jpg
#   inflating: /root/Assignment/cityscapes_data/val/93.jpg
#   inflating: /root/Assignment/cityscapes_data/val/94.jpg
#   inflating: /root/Assignment/cityscapes_data/val/95.jpg
#   inflating: /root/Assignment/cityscapes_data/val/96.jpg
#   inflating: /root/Assignment/cityscapes_data/val/97.jpg
#   inflating: /root/Assignment/cityscapes_data/val/98.jpg
#   inflating: /root/Assignment/cityscapes_data/val/99.jpg

# %%
import os

root_path = '/root/Assignment/cityscapes_data'

data_dir = root_path
train_dir = os.path.join(data_dir, "train")
val_dir = os.path.join(data_dir, "val")
train_fns = os.listdir(train_dir)
val_fns = os.listdir(val_dir)

print(len(train_fns), len(val_fns))  # num of train / test data
# Out:
# 2975 500

# %%
import matplotlib.pyplot as plt
from PIL import Image

sample_image_fp = os.path.join(train_dir, train_fns[0])
sample_image = Image.open(sample_image_fp).convert("RGB")

plt.imshow(sample_image)
plt.show()

image_array = plt.imread(sample_image_fp)
print(image_array.shape)
# Out:
# (256, 512, 3)

# %%
import numpy as np
num_items = 1000
color_array = np.random.choice(range(256), 3*num_items).reshape(-1, 3)
print(color_array.shape)
# Out:
# (1000, 3)

# %%
from sklearn.cluster import KMeans
num_classes = 10
label_model = KMeans(n_clusters = num_classes)
label_model.fit(color_array)
# Out:
# KMeans(n_clusters=10)

# %%
def split_image(image):
   image = np.array(image)
   cityscape, label = image[:, :256, :], image[:, 256:, :]
   return cityscape, label

# %%
cityscape, label = split_image(sample_image)

label_class = label_model.predict(label.reshape(-1, 3)).reshape(256, 256)
fig, axes = plt.subplots(1, 3, figsize = (15, 5))
axes[0].imshow(cityscape)
axes[1].imshow(label)
axes[2].imshow(label_class)

plt.show()

# %%
import torch
from torch.utils.data import Dataset
from torchvision import transforms

class CityscapeDataset(Dataset):

  def __init__(self, image_dir, label_model):
    self.image_dir = image_dir
    self.image_fns = os.listdir(image_dir)
    self.label_model = label_model

  def __len__(self) :
    return len(self.image_fns)

  def __getitem__(self, index) :
    image_fn = self.image_fns[index]
    image_fp = os.path.join(self.image_dir, image_fn)
    image = Image.open(image_fp)
    image = np.array(image)
    cityscape, label = self.split_image(image)
    label_class = self.label_model.predict(label.reshape(-1, 3)).reshape(256, 256)
    label_class = torch.Tensor(label_class).long()
    cityscape = self.transform(cityscape)
    return cityscape, label_class

  def split_image(self, image) :
    image = np.array(image)
    cityscape, label = image[ : , :256, : ], image[ : , 256: , : ]
    return cityscape, label

  def transform(self, image) :
    transform_ops = transforms.Compose([
      			transforms.ToTensor(),
                        transforms.Normalize(mean = (0.485, 0.56, 0.406), std = (0.229, 0.224, 0.225))
    ])
    return transform_ops(image)

dataset = CityscapeDataset(train_dir, label_model)
print(len(dataset))

cityscape, label_class = dataset[0]
print(cityscape.shape)
print(label_class.shape)
# Out:
# 2975
# torch.Size([3, 256, 256])
# torch.Size([256, 256])

# %%
import torch
import torch.nn as nn

class UNet(nn.Module):
    def __init__(self, num_classes):
        super(UNet, self).__init__()

        # Contracting path (Encoder)
        self.encoder1 = self.conv_block(3, 64)  
        self.encoder2 = self.conv_block(64, 128)
        self.encoder3 = self.conv_block(128, 256)
        self.encoder4 = self.conv_block(256, 512)

        # Bottleneck
        self.bottleneck = self.conv_block(512, 1024)

        # Expansive path (Decoder)
        self.upconv4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.decoder4 = self.conv_block(1024, 512)
        self.upconv3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.decoder3 = self.conv_block(512, 256)
        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.decoder2 = self.conv_block(256, 128)
        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.decoder1 = self.conv_block(128, 64)

        # Output layer
        self.output_out = nn.Conv2d(64, num_classes, kernel_size=1)

        # Max Pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def conv_block(self, in_channels, out_channels):
        # basic convolution block with relu, batchnorm
        block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
        return block

    def forward(self, X):
        # Contracting path
        enc1 = self.encoder1(X)                    
        enc2 = self.encoder2(self.pool(enc1))      
        enc3 = self.encoder3(self.pool(enc2))      
        enc4 = self.encoder4(self.pool(enc3))     

        # Bottleneck
        bottleneck = self.bottleneck(self.pool(enc4)) 

        # Expansive path
        dec4 = self.upconv4(bottleneck)               
        dec4 = torch.cat((dec4, enc4), dim=1)         
        dec4 = self.decoder4(dec4)                

        dec3 = self.upconv3(dec4)                   
        dec3 = torch.cat((dec3, enc3), dim=1)   # Skip connection 
        dec3 = self.decoder3(dec3)               

        dec2 = self.upconv2(dec3)                  
        dec2 = torch.cat((dec2, enc2), dim=1)      
        dec2 = self.decoder2(dec2)               

        dec1 = self.upconv1(dec2)                 
        dec1 = torch.cat((dec1, enc1), dim=1)     
        dec1 = self.decoder1(dec1)          

        # Output layer
        output_out = self.output_out(dec1)    

        return output_out

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

model = UNet(num_classes=num_classes)
data_loader = DataLoader(dataset, batch_size = 4)
print(len(dataset), len(data_loader))

X, Y = next(iter(data_loader))
print(X.shape)
print(Y.shape)
# Out:
# 2975 744
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 256, 256])

# %%
Y_pred = model(X)
print(Y_pred.shape)
# Out:
# torch.Size([4, 10, 256, 256])

# %% [markdown]
# # **2. 모델 학습**

# %%
import os
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.optim as optim
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

## 하이퍼파라미터 자율설정

batch_size = 4

epochs = 10
lr = 0.01

dataset = CityscapeDataset(train_dir, label_model)
data_loader = DataLoader(dataset, batch_size = batch_size)

model = UNet(num_classes = num_classes).to(device)

# 손실함수 정의
criterion = nn.CrossEntropyLoss()
# Optimizer 정의
optimizer = optim.Adam(model.parameters(), lr = lr)


step_losses = []  # loss in batch
epoch_losses = [] # loss in epoch

for epoch in tqdm(range(epochs)) :
  epoch_loss = 0

  for X, Y in tqdm(data_loader, total = len(data_loader), leave = False) :
    X, Y = X.to(device), Y.to(device)
    optimizer.zero_grad()
    Y_pred = model(X)
    loss = criterion(Y_pred, Y)
    loss.backward()
    optimizer.step()
    epoch_loss += loss.item()
    step_losses.append(loss.item())
  epoch_losses.append(epoch_loss/len(data_loader))
# Out:
# 100%|██████████| 10/10 [13:15<00:00, 79.55s/it]

# %%
print(len(epoch_losses))
print(epoch_losses)
# Out:
# 10
# [1.0022458178541993, 0.8391796261552842, 0.7721586801031585, 0.722059652890249, 0.6729967168342041, 0.6268313161788448, 0.594068564354412, 0.5684225015262122, 0.545151460555292, 0.5249486077296478]

# %%
##TODO draw a plot!

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].plot(step_losses, color='skyblue')
axes[0].set_title('Step Loss')
axes[0].set_xlabel('Batch')
axes[0].set_ylabel('Loss')

axes[1].plot(epoch_losses, color='plum')
axes[1].set_title('Epoch Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')

plt.show()

# %%
model_name = "UNet.pth"
torch.save(model.state_dict(), root_path + model_name)

# %% [markdown]
# # **3. 모델 평가**

# %%
model_path = root_path + model_name
model_ = UNet(num_classes = num_classes).to(device)
model_.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
test_batch_size = 8
dataset = CityscapeDataset(val_dir, label_model)
data_loader = DataLoader(dataset, batch_size = test_batch_size)

X,Y = next(iter(data_loader))
X,Y = X.to(device), Y.to(device)
Y_pred = model_(X)
print(Y_pred.shape)
Y_pred = torch.argmax(Y_pred, dim=1)
print(Y_pred.shape)
# Out:
# torch.Size([8, 10, 256, 256])
# torch.Size([8, 256, 256])

# %%
inverse_transform = transforms.Compose([
    transforms.Normalize((-0.485/0.229, -0.456/0.224, -0.406/0.225), (1/0.229, 1/0.224, 1/0.225))
])
fig, axes = plt.subplots(test_batch_size, 3, figsize=(3*5, test_batch_size*5))

iou_scores = []

for i in range(test_batch_size):

    landscape = inverse_transform(X[i]).permute(1, 2, 0).cpu().detach().numpy()
    label_class = Y[i].cpu().detach().numpy()
    label_class_predicted = Y_pred[i].cpu().detach().numpy()

    # IOU score
    intersection = np.logical_and(label_class, label_class_predicted)
    union = np.logical_or(label_class, label_class_predicted)
    iou_score = np.sum(intersection) / np.sum(union)
    iou_scores.append(iou_score)

    axes[i, 0].imshow(landscape)
    axes[i, 0].set_title("Landscape")
    axes[i, 1].imshow(label_class)
    axes[i, 1].set_title("Label Class")
    axes[i, 2].imshow(label_class_predicted)
    axes[i, 2].set_title("Label Class - Predicted")

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.096156806..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10399997..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10399997..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10399997..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.096156806..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10399997..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10007839..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10399997..1.0].

# %%
# eval on the entier test dataset

iou_scores = []

for x, y in data_loader:  
    y_pred = model_(x.to(device))
    y = y.to(device)
    
    for i in range(x.size(0)):
        landscape = inverse_transform(X[i]).permute(1, 2, 0).cpu().detach().numpy()
        label_class = Y[i].cpu().detach().numpy()
        label_class_predicted = Y_pred[i].cpu().detach().numpy()

        # calculate IoU
        intersection = np.logical_and(label_class, label_class_predicted)
        union = np.logical_or(label_class, label_class_predicted)
        iou_score = np.sum(intersection) / np.sum(union)
        iou_scores.append(iou_score)

# %%
print(len(iou_scores))
# Out:
# 500

# %% [markdown]
# # **4. IoU Score**

# %%
##TODO IoU score 계산하기

sum(iou_scores) / 500
# Out:
# 0.9354010751874919
